# %%
import pandas as pd
import numpy as np

# %%
# Path to sanitized data
path_metadata = 'data/metadata_sanitized.csv'
path_weather ='data/weather_sanitized.csv'
path_meter_cleaned = 'data/meter_sanitized.csv'

# %%
# load data
metadata = pd.read_csv(path_metadata)
weather = pd.read_csv(path_weather)
meter_all = pd.read_csv(path_meter_cleaned)

# %%
# verify that no values are missing
print('metadata missing values: \n', metadata.isnull().sum() * 100 / len(metadata))
print('weather missing values: \n', weather.isnull().sum() * 100 / len(weather))
print('meter missing values: \n', meter_all.isnull().sum() * 100 / len(meter_all))
# Out:
# metadata missing values:
#  building_id              0.0
# site_id                  0.0
# sqm                      0.0
# primaryspaceusage        0.0
# sub_primaryspaceusage    0.0
# lat                      0.0
# lng                      0.0
# dtype: float64
# weather missing values:
#  timestamp         0.0
# site_id           0.0
# airTemperature    0.0
# dewTemperature    0.0
# seaLvlPressure    0.0
# windDirection     0.0
# windSpeed         0.0
# dtype: float64
# meter missing values:
#  timestamp        0.0
# building_id      0.0
# meter_reading    0.0
# dtype: float64

# %%
# create a small training set with 10 random buildings
metadata = metadata.sample(n=10, random_state=42)
metadata
# Out:
#                   building_id   site_id      sqm  \
# 677      Bear_education_Gavin      Bear   7158.6
# 1589    Cockatoo_lodging_Lana  Cockatoo   4541.2
# 984        Gator_assembly_Roy     Gator   2461.5
# 607           Rat_public_Sana       Rat  37161.2
# 1392        Hog_office_Miriam       Hog   1418.5
# 1033     Bull_education_Shona      Bull   1352.8
# 1582  Cockatoo_lodging_Javier  Cockatoo  12411.3
# 1309      Hog_education_Odell       Hog  14537.7
# 1626   Cockatoo_assembly_Mimi  Cockatoo   1046.6
# 271           Fox_public_Bart       Fox   9407.5
#
#                   primaryspaceusage sub_primaryspaceusage        lat  \
# 677                       Education             Education  37.871903
# 1589            Lodging/residential             Dormitory  42.459837
# 984   Entertainment/public assembly       Sports Facility   0.000000
# 607                 Public services               Library  38.903504
# 1392                         Office                Office  44.978782
# 1033                      Education    College Laboratory  30.267200
# 1582            Lodging/residential             Dormitory  42.459837
# 1309                      Education    College Laboratory  44.978782
# 1626  Entertainment/public assembly             Gymnasium  42.459837
# 271                 Public services               Library  33.424425
#
#              lng
# 677  -122.260729
# 1589  -76.485292
# 984     0.000000
# 607   -77.005349
# 1392  -93.255398
# 1033  -97.743100
# 1582  -76.485292
# 1309  -93.255398
# 1626  -76.485292
# 271  -111.928140

# %%
# get the meter data for the selected buildings
meter = meter_all[meter_all['building_id'].isin(metadata['building_id'])]

# %%
# add site_id to the meter data by getting first word of building_id
meter['site_id'] = meter['building_id'].apply(lambda x: x.split('_')[0])
meter
# Out:
# /tmp/ipykernel_7803/3220531755.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meter['site_id'] = meter['building_id'].apply(lambda x: x.split('_')[0])
#                     timestamp              building_id  meter_reading  \
# 3649152   2016-01-01 00:00:00          Fox_public_Bart         46.290
# 3649153   2016-01-01 01:00:00          Fox_public_Bart         36.790
# 3649154   2016-01-01 02:00:00          Fox_public_Bart         36.520
# 3649155   2016-01-01 03:00:00          Fox_public_Bart         37.520
# 3649156   2016-01-01 04:00:00          Fox_public_Bart         38.090
# ...                       ...                      ...            ...
# 26508979  2017-12-31 19:00:00  Cockatoo_lodging_Javier         46.425
# 26508980  2017-12-31 20:00:00  Cockatoo_lodging_Javier         47.200
# 26508981  2017-12-31 21:00:00  Cockatoo_lodging_Javier         47.475
# 26508982  2017-12-31 22:00:00  Cockatoo_lodging_Javier         47.700
# 26508983  2017-12-31 23:00:00  Cockatoo_lodging_Javier         45.675
#
#            site_id
# 3649152        Fox
# 3649153        Fox
# 3649154        Fox
# 3649155        Fox
# 3649156        Fox
# ...            ...
# 26508979  Cockatoo
# 26508980  Cockatoo
# 26508981  Cockatoo
# 26508982  Cockatoo
# 26508983  Cockatoo
#
# [175440 rows x 4 columns]

# %%
weather
# Out:
#                   timestamp  site_id  airTemperature  dewTemperature  \
# 0       2016-01-01 00:00:00  Panther            19.4            19.4
# 1       2016-01-01 01:00:00  Panther            21.1            21.1
# 2       2016-01-01 02:00:00  Panther            21.1            21.1
# 3       2016-01-01 03:00:00  Panther            20.6            20.0
# 4       2016-01-01 04:00:00  Panther            21.1            20.6
# ...                     ...      ...             ...             ...
# 331161  2017-12-31 19:00:00    Mouse             8.5             4.8
# 331162  2017-12-31 20:00:00    Mouse             8.5             4.5
# 331163  2017-12-31 21:00:00    Mouse             8.2             4.0
# 331164  2017-12-31 22:00:00    Mouse             7.5             4.3
# 331165  2017-12-31 23:00:00    Mouse             7.2             3.7
#
#         seaLvlPressure  windDirection  windSpeed
# 0               1019.4            0.0        0.0
# 1               1019.4            0.0        0.0
# 2               1019.4          210.0        1.5
# 3               1019.4            0.0        0.0
# 4               1019.4          290.0        1.5
# ...                ...            ...        ...
# 331161           992.3          210.0        8.2
# 331162           992.1          210.0        7.2
# 331163           992.1          230.0       10.3
# 331164           993.7          260.0       12.9
# 331165           995.7          260.0       10.3
#
# [331166 rows x 7 columns]

# %%
# add weather data to meter data based on site_id
meter = meter.merge(weather, on=['timestamp', 'site_id'], how='left')
meter
# Out:
#                   timestamp              building_id  meter_reading   site_id  \
# 0       2016-01-01 00:00:00          Fox_public_Bart         46.290       Fox
# 1       2016-01-01 01:00:00          Fox_public_Bart         36.790       Fox
# 2       2016-01-01 02:00:00          Fox_public_Bart         36.520       Fox
# 3       2016-01-01 03:00:00          Fox_public_Bart         37.520       Fox
# 4       2016-01-01 04:00:00          Fox_public_Bart         38.090       Fox
# ...                     ...                      ...            ...       ...
# 175435  2017-12-31 19:00:00  Cockatoo_lodging_Javier         46.425  Cockatoo
# 175436  2017-12-31 20:00:00  Cockatoo_lodging_Javier         47.200  Cockatoo
# 175437  2017-12-31 21:00:00  Cockatoo_lodging_Javier         47.475  Cockatoo
# 175438  2017-12-31 22:00:00  Cockatoo_lodging_Javier         47.700  Cockatoo
# 175439  2017-12-31 23:00:00  Cockatoo_lodging_Javier         45.675  Cockatoo
#
#         airTemperature  dewTemperature  seaLvlPressure  windDirection  \
# 0                  7.2            -5.6          1017.3            0.0
# 1                  7.2            -6.7          1017.0           50.0
# 2                  6.1            -5.0          1016.9            0.0
# 3                  5.0            -5.6          1017.4            0.0
# 4                  4.4            -5.6          1017.2            0.0
# ...                ...             ...             ...            ...
# 175435             NaN             NaN             NaN            NaN
# 175436           -16.7           -20.0          1028.7          270.0
# 175437           -16.1           -18.9          1028.5          290.0
# 175438           -15.6           -17.8          1028.3          290.0
# 175439           -15.0           -17.2          1028.4          310.0
#
#         windSpeed
# 0             0.0
# 1             1.5
# 2             0.0
# 3             0.0
# 4             0.0
# ...           ...
# 175435        NaN
# 175436        5.7
# 175437        5.1
# 175438        5.7
# 175439        6.7
#
# [175440 rows x 9 columns]

# %%
# check if there are any missing values
meter.isnull().sum() * 100 / len(meter)
# Out:
# timestamp         0.000000
# building_id       0.000000
# meter_reading     0.000000
# site_id           0.000000
# airTemperature    0.988372
# dewTemperature    0.988372
# seaLvlPressure    0.988372
# windDirection     0.988372
# windSpeed         0.988372
# dtype: float64

# %%
# interpolate missing values
meter = meter.interpolate(limit_direction='both')

# %%
# save the small dataset
meter.to_csv('data/dataset_small.csv', index=False)
